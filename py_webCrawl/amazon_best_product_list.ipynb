# %% [markdown]
# # 아마존 카테고리 별 상품 수집

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import sys
import re
import math
import numpy 
import pandas as pd   
import openpyxl 
import random
import os


import urllib.request
import urllib

# %%
# 카테고리 값을 입력받아 해당 카테고리 메뉴 실행

query_txt='아마존닷컴'
query_url='https://www.amazon.com/bestsellers?ld=NSGoogle'

sec = input('''
    1.Amazon Devices & Accessories     2.Amazon Explore              3.Amazon Launchpad 
    4.Appliances                       5.Apps & Games                6.Arts, Crafts & Sewing
    7.Audible Books & Originals        8.Automotive                  9.Baby
    10.Beauty & Personal Care          11.Books                      12.Camera & Photo Products
    13.CDs & Vinyl                     14.Cell Phones & Accessories  15.Clothing, Shoes & Jewelry
    16.Collectible Coins               17.Computers & Accessories    18.Digital Educational Resources
    19.Digital Music                   20.Electronics                21.Entertainment Collectibles
    22.Gift Cards                      23.Grocery & Gourmet Food     24.Handmade Products
    25.Health & Household              26.Home & Kitchen             27.Industrial & Scientific
    28.Kindle Store                    29.Kitchen & Dining           30.Magazine Subscriptions
    31.Movies & TV                     32.Musical Instruments        33.Office Products
    34.Patio, Lawn & Garden            35.Pet Supplies               36.Software
    37.Sports & Outdoors               38.Sports Collectibles        39.Tools & Home Improvement   
    40.Toys & Games                    41.Video Games

    1. 수집할 카테고리의 번호 입력: ''')

cnt = int(input('2. 크롤링 할 건수 입력(1-100건): '))

f_dir = input('3. 파일을 저장할 폴더명 입력(ex c:\\temp\\): ')

if sec == '1' :
      sec_name='Amazon Devices and Accessories'
elif sec =='2' :
      sec_name='Amazon Explore'
elif sec =='3' :
      sec_name='Amazon Launchpad'
elif sec =='4' :
      sec_name='Appliances'
elif sec =='5' :
      sec_name='Apps & Games'
elif sec =='6' :
      sec_name='Arts, Crafts & Sewing'
elif sec =='7' :
      sec_name='Audible Books & Originals'
elif sec =='8' :
      sec_name='Automotive'
elif sec =='9' :
      sec_name='Baby'
elif sec =='10' :
      sec_name='Beauty & Personal Care'
elif sec =='11' :
      sec_name='Books'
elif sec =='12' :
      sec_name='Camera & Photo Products'
elif sec =='13' :
      sec_name='CDs and Vinyl'
elif sec =='14' :
      sec_name='Cell Phones & Accessories'
elif sec =='15' :
      sec_name='Clothing, Shoes & Jewelry'
elif sec =='16' :
      sec_name='Collectible Coins'
elif sec =='17' :
      sec_name='Computers & Accessories'
elif sec =='18' :
      sec_name='Digital Educational Resources'
elif sec =='19' :
      sec_name='Digital Music'
elif sec =='20' :
      sec_name='Electronics'
elif sec =='21' :
      sec_name='Entertainment Collectibles'
elif sec =='22' :
      sec_name='Gift Cards'
elif sec =='23' :
      sec_name='Grocery & Gourmet Food'
elif sec =='24' :
      sec_name='Handmade Products'
elif sec =='25' :
      sec_name='Health & Household'
elif sec =='26' :
      sec_name='Home & Kitchen'
elif sec =='27' :
      sec_name='Industrial & Scientific'
elif sec =='28' :
      sec_name='Kindle Store'
elif sec =='29' :
      sec_name='Kitchen & Dining'
elif sec =='30' :
      sec_name='Magazine Subscriptions'
elif sec =='31' :
      sec_name='Movies & TV'
elif sec =='32' :
      sec_name='Musical Instruments'
elif sec =='33' :
      sec_name='Office Products'
elif sec =='34' :
      sec_name='Patio, Lawn & Garden'
elif sec =='35' :
      sec_name='Pet Supplies'
elif sec =='36' :
      sec_name='Software'
elif sec =='37' :
      sec_name='Sports & Outdoors'
elif sec =='38' :
      sec_name='Sports Collectibles'
elif sec =='39' :
      sec_name='Tools & Home Improvement'
elif sec =='40' :
      sec_name='Toys & Games'
elif sec =='41' :
      sec_name='Video Games'
        
if cnt > 30:
    print('요청건수가 많아 시간이 다소 소요됩니다.')
else:
    print('요청 데이터 수집 중...')
# Out:
#     1.Amazon Devices & Accessories     2.Amazon Explore              3.Amazon Launchpad
#     4.Appliances                       5.Apps & Games                6.Arts, Crafts & Sewing
#     7.Audible Books & Originals        8.Automotive                  9.Baby
#     10.Beauty & Personal Care          11.Books                      12.Camera & Photo Products
#     13.CDs & Vinyl                     14.Cell Phones & Accessories  15.Clothing, Shoes & Jewelry
#     16.Collectible Coins               17.Computers & Accessories    18.Digital Educational Resources
#     19.Digital Music                   20.Electronics                21.Entertainment Collectibles
#     22.Gift Cards                      23.Grocery & Gourmet Food     24.Handmade Products
#     25.Health & Household              26.Home & Kitchen             27.Industrial & Scientific
#     28.Kindle Store                    29.Kitchen & Dining           30.Magazine Subscriptions
#     31.Movies & TV                     32.Musical Instruments        33.Office Products
#     34.Patio, Lawn & Garden            35.Pet Supplies               36.Software
#     37.Sports & Outdoors               38.Sports Collectibles        39.Tools & Home Improvement
#     40.Toys & Games                    41.Video Games
#
#     1. 수집할 카테고리의 번호 입력: 1
# 2. 크롤링 할 건수 입력(1-100건): 60
# 3. 파일을 저장할 폴더명 입력(ex c:\temp\): C:\Users\socsoft\Downloads\internship_kwj\

# %%
#  timeout: Timed out receiving message from renderer 오류
# from pyvirtualdisplay import Display
# display = Display(visible=0, size=(1024,768))
# display.start()

now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt+'-'+sec_name)
os.chdir(f_dir+s+'-'+query_txt+'-'+sec_name)

ff_dir=f_dir+s+'-'+query_txt+'-'+sec_name
ff_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.txt'
fc_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.csv'
fx_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.xlsx'

s_time = time.time( )

path = 'C:/Users/SOCSOFT/Downloads/internship_kwj/chromedriver.exe'
driver = webdriver.Chrome(path)
    
driver.get(query_url)
time.sleep(5)

# 카테고리 별 더보기 페이지
# 그냥 xPath는 클릭이 안되는데 full xPath는 클릭이 되는 현상...

if sec == '1' :
    driver.find_element_by_xpath("""/html/body/div[1]/div[2]/div[2]/div/div/div/div[2]/div/div[2]/div/div/div[2]/div[1]/a""").click( )
elif sec == '2' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[2]/a""").click( )
elif sec == '3' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[3]/a""").click( )
elif sec == '4' : 
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[4]/a""").click( )
elif sec == '5' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[5]/a""").click( )
elif sec == '6' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[6]/a""").click( )
elif sec == '7' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[7]/a""").click( )  
elif sec == '8' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[8]/a""").click( )
elif sec == '9' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[9]/a""").click( )
elif sec == '10' : 
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[10]/a""").click( )
elif sec == '11' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[11]/a""").click( )
elif sec == '12' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[12]/a""").click( )
elif sec == '13' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[13]/a""").click( )
elif sec == '14' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[14]/a""").click( )
elif sec == '15' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[15]/a""").click( )
elif sec == '16' : 
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[16]/a""").click( )
elif sec == '17' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[17]/a""").click( )
elif sec == '18' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[18]/a""").click( )
elif sec == '19' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[19]/a""").click( )
elif sec == '20' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[20]/a""").click( )
elif sec == '21' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[21]/a""").click( )
elif sec == '22' : 
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[22]/a""").click( )
elif sec == '23' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[23]/a""").click( )
elif sec == '24' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[24]/a""").click( )
elif sec == '25' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[25]/a""").click( )
elif sec == '26' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[26]/a""").click( )
elif sec == '27' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[27]/a""").click( )
elif sec == '28' : 
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[28]/a""").click( )
elif sec == '29' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[29]/a""").click( )
elif sec == '30' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[30]/a""").click( )
elif sec == '31' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[31]/a""").click( )
elif sec == '32' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[32]/a""").click( )
elif sec == '33' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[33]/a""").click( )
elif sec == '34' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[34]/a""").click( )
elif sec == '35' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[35]/a""").click( )
elif sec == '36' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[36]/a""").click( )
elif sec == '37' : 
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[37]/a""").click( )
elif sec == '38' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[38]/a""").click( )
elif sec == '39' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[39]/a""").click( )
elif sec == '40' :
      driver.find_element_by_xpath("""//*[@id="zg_browseRoot"]/ul/li[40]/a""").click( )

time.sleep(1)

# %%
# 스크롤 후 데이터 수집

def scroll_down(driver):
    driver.execute_script('window.scrollBy(0, 18000);')
    time.sleep(1)
    
scroll_down(driver)

# 비트맵 이미지 아이콘을 위한 대체 딕셔너리 생성
bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

comm_result = soup.select_one('#zg-right-col').find('div', 'p13n-gridRow _cDEzb_grid-row_3Cywl').select('#gridItemRoot')

# %%
if cnt < 51 :
    ranking_li=[]
    title_li=[]
    price_li=[]
    score_li=[]
    sat_count_li=[]
    store_li=[]
    
    count = 0
    
    for li in comm_result:
        
        f = open(ff_name, 'a',encoding='UTF-8')
        f.write("-----------------------------------------------------"+"\n")
        
        # 판매순위
        try:
            ranking = li.find('span', 'zg-bdg-text').get_text().replace("#","")
        except AttributeError:
            ranking = ''
            print(ranking.replace("#",""))
        else:
            print("1.판매순위:",ranking)
        f.write('1.판매순위:'+ ranking + "\n")
        
        #제품 설명 
        try :
            title = li.find('div',class_='_cDEzb_p13n-sc-css-line-clamp-3_g3dy1').get_text().replace("\n","")
        except AttributeError :
            title = ''
            print(title.replace("\n",""))
            f.write('2.제품소개:'+ title + "\n")
        else :
            title_2=title.translate(bmp_map).replace("\n","") 
            print("2.제품소개:", title_2.replace("\n",""))

            count += 1
             
            f.write('2.제품소개:'+ title_2 + "\n")
            
        # 가격
        try :
            price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            print("3.가격:", price)
        except AttributeError :
            price = ''
            print("3.가격:", price.replace("\n",""))
            f.write('3.가격:'+ price + "\n")
            
        # 상품평 수
        try :
            sat_count = li.find('span','a-size-small').get_text().replace(",","")
        except (IndexError , AttributeError) :
            sat_count='0'
            print('4.상품평 수: ',sat_count)
            f.write('4.상품평 수:'+ sat_count + "\n")
        else :
            print('4.상품평 수:',sat_count)
            f.write('4.상품평 수:'+ sat_count + "\n")
            
        #상품 별점 구하기
        try :
             score = li.find('span','a-icon-alt').get_text()
        except AttributeError :
             score=' '

        print('5.평점:',score)
        f.write('5.평점:'+ score + "\n")

        print("-" *70)

        f.close( )

        time.sleep(0.3)

        ranking_li.append(ranking)
        title_li.append(title_2.replace("\n",""))
        price_li.append(price.replace("\n",""))

        try :   
            sat_count_li.append(sat_count)
        except IndexError :
            sat_count_li.append(0)

        score_li.append(score)

        if count == cnt :
            break
            
elif cnt >= 51 :
    
    ranking_li=[]
    title_li=[]
    price_li=[]
    score_li=[]
    sat_count_li=[]
    store_li=[]
    
    for li in comm_result:
        
        f = open(ff_name, 'a',encoding='UTF-8')
        f.write("-----------------------------------------------------"+"\n")
        
        # 판매순위
        try:
            ranking = li.find('span', 'zg-bdg-text').get_text().replace("#","")
        except AttributeError:
            ranking = ''
            print(ranking.replace("#",""))
        else:
            print("1.판매순위:",ranking)
        f.write('1.판매순위:'+ ranking + "\n")
        
        #제품 설명 
        try :
            title = li.find('div',class_='_cDEzb_p13n-sc-css-line-clamp-3_g3dy1').get_text().replace("\n","")
        except AttributeError :
            title = ''
            print(title.replace("\n",""))
            f.write('2.제품소개:'+ title + "\n")
        else :
            title_2=title.translate(bmp_map).replace("\n","") 
            print("2.제품소개:", title_2.replace("\n",""))

            count += 1
             
            f.write('2.제품소개:'+ title_2 + "\n")
            
        # 가격
        try :
            price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            print("3.가격:", price)
        except AttributeError :
            price = ''
            print("3.가격:", price.replace("\n",""))
            f.write('3.가격:'+ price + "\n")
            
        # 상품평 수
        try :
            sat_count = li.find('span','a-size-small').get_text().replace(",","")
        except (IndexError , AttributeError) :
            sat_count='0'
            print('4.상품평 수: ',sat_count)
            f.write('4.상품평 수:'+ sat_count + "\n")
        else :
            print('4.상품평 수:',sat_count)
            f.write('4.상품평 수:'+ sat_count + "\n")
            
        #상품 별점 구하기
        try :
             score = li.find('span','a-icon-alt').get_text()
        except AttributeError :
             score=' '

        print('5.평점:',score)
        f.write('5.평점:'+ score + "\n")

        print("-" *70)

        f.close( )

        time.sleep(0.5)

        ranking_li.append(ranking)
        title_li.append(title_2.replace("\n",""))
        price_li.append(price.replace("\n",""))

        try :   
            sat_count_li.append(sat_count)
        except IndexError :
            sat_count_li.append(0)

        score_li.append(score)

        time.sleep(0.5)
# 1페이지에서 2페이지로 넘어가기
    driver.find_element_by_xpath('''/html/body/div[1]/div[3]/div/div/div[1]/div/div/div[2]/div[2]/ul/li[4]/a''').click()
    print('\n')
    
    # 스크롤 후 데이터 수집

    def scroll_down(driver):
        driver.execute_script('window.scrollBy(0, 9300);')
        time.sleep(1)

    scroll_down(driver)

    # 비트맵 이미지 아이콘을 위한 대체 딕셔너리 생성
    bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    comm_result2 = soup.select_one('#zg-right-col').find('div', 'p13n-gridRow _cDEzb_grid-row_3Cywl').select('#gridItemRoot')

    for li in comm_result2:
        
        f = open(ff_name, 'a',encoding='UTF-8')
        f.write("-----------------------------------------------------"+"\n")
        
        # 판매순위
        try:
            ranking = li.find('span', 'zg-bdg-text').get_text().replace("#","")
        except AttributeError:
            ranking = ''
            print(ranking.replace("#",""))
        else:
            print("1.판매순위:",ranking)
        f.write('1.판매순위:'+ ranking + "\n")
        
        #제품 설명 
        try :
            title = li.find('div',class_='_cDEzb_p13n-sc-css-line-clamp-3_g3dy1').get_text().replace("\n","")
        except AttributeError :
            title = ''
            print(title.replace("\n",""))
            f.write('2.제품소개:'+ title + "\n")
        else :
            title_2=title.translate(bmp_map).replace("\n","") 
            print("2.제품소개:", title_2.replace("\n",""))

            count += 1
             
            f.write('2.제품소개:'+ title_2 + "\n")
            
        # 가격
        try :
            price = li.find('span','p13n-sc-price').get_text().replace("\n","")
            print("3.가격:", price)
        except AttributeError :
            price = ''
            print("3.가격:", price.replace("\n",""))
            f.write('3.가격:'+ price + "\n")
            
        # 상품평 수
        try :
            sat_count = li.find('span','a-size-small').get_text().replace(",","")
        except (IndexError , AttributeError) :
            sat_count='0'
            print('4.상품평 수: ',sat_count)
            f.write('4.상품평 수:'+ sat_count + "\n")
        else :
            print('4.상품평 수:',sat_count)
            f.write('4.상품평 수:'+ sat_count + "\n")
            
        #상품 별점 구하기
        try :
             score = li.find('span','a-icon-alt').get_text()
        except AttributeError :
             score=' '

        print('5.평점:',score)
        f.write('5.평점:'+ score + "\n")

        print("-" *70)

        f.close( )

        time.sleep(0.5)

        ranking_li.append(ranking)
        title_li.append(title_2.replace("\n",""))
        price_li.append(price.replace("\n",""))

        try :   
            sat_count_li.append(sat_count)
        except IndexError :
            sat_count_li.append(0)

        score_li.append(score)
        
        if count == cnt:
            break
else:
    print('검색 건수는 최대 100건까지만 가능합니다.')

# %%
#Step 5. 검색 결과를 다양한 형태로 저장하기
              
amazon_best_seller = pd.DataFrame()
amazon_best_seller['판매순위']=ranking_li
amazon_best_seller['제품소개']=pd.Series(title_li)
amazon_best_seller['판매가격']=pd.Series(price_li)
amazon_best_seller['상품평 갯수']=pd.Series(sat_count_li)
amazon_best_seller['상품평점']=pd.Series(score_li)


# csv 형태로 저장하기
amazon_best_seller.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장하기
amazon_best_seller.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time

# txt 파일에 크롤링 요약 정보 저장하기
orig_stdout = sys.stdout
f = open(ff_name, 'a',encoding='UTF-8')
sys.stdout = f

# %% [markdown]
# ---

# %% [markdown]
# - 구조가 달라 나오지 않는 데이터들 수정 필요
# - 입력한 cnt보다 많이 나오는 현상 수정 필요
# - 코드 더 간단히 수정 필요
